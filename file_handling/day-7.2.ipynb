# %% [markdown]
# read csv files in pandas

# %%
import pandas as pd

df = pd.read_csv('person_data.csv')  # Load data from a CSV file
print(df)

# %% [markdown]
# read json files in pandas

# %%
import pandas as pd

df = pd.read_json('my_json.json')  # Load data from a JSON file
print(df)
